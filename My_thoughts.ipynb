# %% [markdown]
# <a href="https://colab.research.google.com/github/Tristyn-Garza/ai-thoughts/blob/main/My_thoughts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## notes I have on AI course so far
# * I've learned hpg and how to see what resources we have.
# * Also found a workaround for being unable to "save a copy to Github"
#   * if saved to google drive I can then "save a copy to Github" just not directly from opened notebook from Github.
# * let's keep going!
